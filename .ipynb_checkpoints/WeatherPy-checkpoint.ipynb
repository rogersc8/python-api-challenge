# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import sys
sys.path.append("/anaconda3/lib/python3.7/site-packages")
from citipy import citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Import API key
from api_keys import api_key
# !pip install citipy

# Incorporated citipy to determine city based on latitude and longitude
#from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
record_counter = 0
set_counter = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    print(url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | mizan teferi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 2 of set 0 | paseh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# City not found!
# Processing record 3 of set 0 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 4 of set 0 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 5 of set 0 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# City not found!
# Processing record 6 of set 0 | teya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 7 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 8 of set 0 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 9 of set 0 | nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 10 of set 0 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# City not found!
# Processing record 11 of set 0 | bimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 12 of set 0 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 13 of set 0 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 14 of set 0 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 15 of set 0 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 16 of set 0 | bondo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 17 of set 0 | praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 18 of set 0 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# City not found!
# Processing record 19 of set 0 | kota belud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 20 of set 0 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 21 of set 0 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 22 of set 0 | uzumlu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# City not found!
# Processing record 23 of set 0 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 24 of set 0 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 25 of set 0 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 26 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 27 of set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 28 of set 0 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 29 of set 0 | newcastle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 30 of set 0 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 31 of set 0 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 32 of set 0 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 33 of set 0 | aketi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 34 of set 0 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 35 of set 0 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 36 of set 0 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 37 of set 0 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 38 of set 0 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 39 of set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 40 of set 0 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 41 of set 0 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# City not found!
# Processing record 42 of set 0 | tupanatinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 43 of set 0 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# City not found!
# Processing record 44 of set 0 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 45 of set 0 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 46 of set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 47 of set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 48 of set 0 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 49 of set 0 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 50 of set 0 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 0 of set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 1 of set 1 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 2 of set 1 | tigil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 3 of set 1 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 4 of set 1 | beruwala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 5 of set 1 | semnan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 6 of set 1 | tay ninh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 7 of set 1 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 8 of set 1 | presidencia roque saenz pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 9 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 10 of set 1 | neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 11 of set 1 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 12 of set 1 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# City not found!
# Processing record 13 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 14 of set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 15 of set 1 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 16 of set 1 | mansa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 17 of set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 18 of set 1 | bose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 19 of set 1 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 20 of set 1 | svecha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 21 of set 1 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 22 of set 1 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 23 of set 1 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# City not found!
# Processing record 24 of set 1 | charters towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 25 of set 1 | naryan-mar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 26 of set 1 | chone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 27 of set 1 | fuxin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 28 of set 1 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 29 of set 1 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# City not found!
# Processing record 30 of set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 31 of set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 32 of set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 33 of set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 34 of set 1 | saiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 35 of set 1 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 36 of set 1 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 37 of set 1 | bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 38 of set 1 | evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 39 of set 1 | maxixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record

# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 36 of set 11 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 37 of set 11 | churapcha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 38 of set 11 | merville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 39 of set 11 | synya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 40 of set 11 | mackenzie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 41 of set 11 | luis correia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 42 of set 11 | pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# Processing record 43 of set 11 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = pd.DataFrame({'City': new_cities,
                            'Latitude': lat,
                            'Longitude': lng,
                            'Temperature': temp,
                            'Humidity': humidity,
                            'Cloudiness': cloudiness,
                            'Wind Speed': wind,
                            'Date' : date,
                            'Country' : country})

# %%
pd.DataFrame.to_csv(city_data_df, 'city_data.csv')

city_data_df.head()
# Out:
#            City  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0  mizan teferi      6.99      35.58        60.21        91           0
# 1  kruisfontein    -34.00      24.73        63.68        44         100
# 2         vaini     15.34      74.49        68.36        98          88
# 3          teya     21.05     -89.07        93.20        52          40
# 4       rikitea    -23.12    -134.97        71.19        83          80
#
#    Wind Speed        Date Country
# 0        3.78  1571957095      ET
# 1        7.29  1571957096      ZA
# 2        5.93  1571957096      IN
# 3       16.11  1571957096      MX
# 4       28.81  1571957096      PF

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_df['Latitude'], city_data_df['Temperature'])
plt.title(f'City Latitude vs. Temperature {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid(True)
plt.savefig('lat_temp.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-b964c37cb178> in <module>
#       1 plt.scatter(city_data_df['Latitude'], city_data_df['Temperature'])
# ----> 2 plt.title(f'City Latitude vs. Temperature {date.today()}')
#       3 plt.xlabel('Latitude')
#       4 plt.ylabel('Temperature (F)')
#       5 plt.grid(True)
#
# AttributeError: 'list' object has no attribute 'today'

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_df['Latitude'], city_data_df['Humidity'])
plt.title(f'City Latitude vs. Humidity {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
plt.savefig('lat_humid.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-5d308bda9191> in <module>
#       1 plt.scatter(city_data_df['Latitude'], city_data_df['Humidity'])
# ----> 2 plt.title(f'City Latitude vs. Humidity {date.today()}')
#       3 plt.xlabel('Latitude')
#       4 plt.ylabel('Humidity (%)')
#       5 plt.grid(True)
#
# AttributeError: 'list' object has no attribute 'today'

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df['Latitude'], city_data_df['Cloudiness'])
plt.title(f'City Latitude vs. Cloudiness {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
plt.savefig('lat_cloud.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-d9f3c6f89d28> in <module>
#       1 plt.scatter(city_data_df['Latitude'], city_data_df['Cloudiness'])
# ----> 2 plt.title(f'City Latitude vs. Cloudiness {date.today()}')
#       3 plt.xlabel('Latitude')
#       4 plt.ylabel('Cloudiness (%)')
#       5 plt.grid(True)
#
# AttributeError: 'list' object has no attribute 'today'

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df['Latitude'], city_data_df['Wind Speed'])
plt.title(f'City Latitude vs. Wind Speed {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
plt.savefig('lat_wind.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-b6dfeb2be9a1> in <module>
#       1 plt.scatter(city_data_df['Latitude'], city_data_df['Wind Speed'])
# ----> 2 plt.title(f'City Latitude vs. Wind Speed {date.today()}')
#       3 plt.xlabel('Latitude')
#       4 plt.ylabel('Wind Speed (mph)')
#       5 plt.grid(True)
#
# AttributeError: 'list' object has no attribute 'today'
